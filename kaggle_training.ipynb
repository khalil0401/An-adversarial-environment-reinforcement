# %% [markdown]
# # LLM-Driven Adversarial RL for IDS (Training Notebook)
#
# This notebook runs the full training pipeline.
#
# ## 1. Setup Environment

# %%
# !git clone https://github.com/khalil0401/An-adversarial-environment-reinforcement.git
# %cd An-adversarial-environment-reinforcement
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Check GPU

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))

# %% [markdown]
# ## 3. Option A: Quick Synthetic Test
# Run this to verify the code works without the dataset.

# %%
# !python -m src.train --episodes 10 --synthetic --use_llm

# %% [markdown]
# ## 4. Option B: Full Training (Real Data)
# **Pre-requisite:** Ad the **TON_IoT Dataset** to your Kaggle environment.
# Run this cell for actual training.

# %%
# Update the path below to match your Kaggle input directory usage
DATA_PATH = "/kaggle/input/ton-iot-network-dataset/train_test_network.csv"

# !python -m src.train --episodes 500 --data_path "$DATA_PATH" --use_llm
