# %% [markdown]
# # LLM-Driven Adversarial RL for IDS (Training Notebook)
#
# This notebook runs the full training pipeline for the Adversarial RL Intrusion Detection System.
#
# ## 1. Setup Environment

# %%
# !git clone https://github.com/khalil0401/An-adversarial-environment-reinforcement.git
# %cd An-adversarial-environment-reinforcement
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Helper: Check GPU

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("Device:", torch.cuda.get_device_name(0))

# %% [markdown]
# ## 3. Run Training (Full Mode)
#
# **Note using Dataset**:
# If you have uploaded the TON_IoT dataset to Kaggle (e.g., `input/ton-iot`), update the `--data_path` argument below.
# Otherwise, use `--synthetic` for a quick test run.

# %%
# Option A: Synthetic Test (No Dataset required)
# !python -m src.train --episodes 20 --synthetic --use_llm

# Option B: Full Training (Uncomment and set path)
# !python -m src.train --episodes 500 --data_path "/kaggle/input/ton_iot/Train_Test_Network.csv" --use_llm

# %% [markdown]
# ## 4. Evaluation & Logs
# Check the `results/` directory for checkpoints.

# %%
# !ls -lh results/
